# %% [markdown]
# ## Introduction to Database Mangement System

# %% [markdown]
# - Database mangement system is a specilized software used to store, manage, organize, and manipulate data efficiently.
# -
